# %% [markdown]
# # The Data

# %% [markdown]
# # Introduction
#
# **Description:**
# The dataset I decided to look at is called "UFO Sightings" and includes over 80,000 records of UFO sightings around the world.  This dataset includes the UFO's shape, the location of the sighting including the coordinates/country/state, the duration of the sighting, and the time of the sighting.
#
# **Link:**
# https://corgis-edu.github.io/corgis/datasets/csv/ufo_sightings/ufo_sightings.csv
#
# **Motivation:**
# My motivation for looking at this data is because I have an interest in conspiracy theories and extraterrestial beings and I would like to figure out whether there are patterns behind UFO sightings and what these patterns could mean.
#
# **Questions:**
# * Is there a pattern among the most common times and location of UFO sightings?
# * Is there a common theme with the locations that have the most common UFO sightings?
# * Does the duration of the UFO sighting play an important role?
# * Do these patterns imply that these UFO sightings can be credible or debunked?

# %% [markdown]
# # Methods

# %%
import pandas as pd

# %%
import requests
response=requests.get('https://corgis-edu.github.io/corgis/datasets/csv/ufo_sightings/ufo_sightings.csv')
response
# Out:
# <Response [200]>

# %% [markdown]
# **Data Summary:**
# The dataset includes the shape of the UFO, the location of the sighting (city and state), the duration of the encounter, a short description of the sighting, coordinates of the sighting, and the time and date of the sighting (month, day, hour, minute, year), and the date that the sighting was documented. All of the data is numerical except for the description, shape, and location which is categorical.

# %%
url='https://corgis-edu.github.io/corgis/datasets/csv/ufo_sightings/ufo_sightings.csv'
df=pd.read_csv(url)
df.head(5)
# Out:
#   Location.City Location.State Location.Country Data.Shape  \
# 0  anchor point             AK               US       disk
# 1     anchorage             AK               US   changing
# 2     anchorage             AK               US   changing
# 3     anchorage             AK               US      cigar
# 4     anchorage             AK               US     circle
#
#    Data.Encounter duration                           Data.Description excerpt  \
# 0                    300.0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...
# 1                  21600.0  We could observe red lights dancing across the...
# 2                    600.0  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...
# 3                     15.0  I explained away the first time I thought I se...
# 4                    300.0  Orange circles &quot;climbing&quot; then fadin...
#
#    Location.Coordinates.Latitude   Location.Coordinates.Longitude   \
# 0                       59.776667                      -151.831389
# 1                       61.218056                      -149.900278
# 2                       61.218056                      -149.900278
# 3                       61.218056                      -149.900278
# 4                       61.218056                      -149.900278
#
#    Dates.Sighted.Year  Dates.Sighted.Month  Date.Sighted.Day  \
# 0                2005                    5                24
# 1                2000                   12                31
# 2                2006                   10                23
# 3                2014                    3                29
# 4                2011                   10                21
#
#    Dates.Sighted.Hour  Dates.Sighted.Minute  Dates.Documented.Year  \
# 0                  18                    30                   2005
# 1                  21                     0                   2001
# 2                  21                     3                   2006
# 3                  20                    45                   2014
# 4                  21                     0                   2011
#
#    Dates.Documented.Month  Dates.Documented.Day
# 0                       5                    28
# 1                       2                    18
# 2                      12                     7
# 3                       4                     4
# 4                      10                    25

# %% [markdown]
# **Summary Statistics**

# %%
df.describe()
# Out:
#        Data.Encounter duration  Location.Coordinates.Latitude   \
# count             6.063200e+04                    60632.000000
# mean              5.410128e+03                       38.311073
# std               4.143867e+05                        5.552705
# min               1.000000e-02                       19.426944
# 25%               3.000000e+01                       34.092222
# 50%               1.800000e+02                       38.904306
# 75%               6.000000e+02                       41.924583
# max               6.627600e+07                       70.636944
#
#        Location.Coordinates.Longitude   Dates.Sighted.Year  \
# count                     60632.000000        60632.000000
# mean                        -95.584796         2004.447833
# std                          18.025296           10.178389
# min                        -170.478889         1910.000000
# 25%                        -114.336667         2002.000000
# 50%                         -89.911111         2007.000000
# 75%                         -81.035000         2011.000000
# max                         -66.984722         2014.000000
#
#        Dates.Sighted.Month  Date.Sighted.Day  Dates.Sighted.Hour  \
# count         60632.000000      60632.000000        60632.000000
# mean              6.872658         15.026587           15.809094
# std               3.249002          8.920703            7.537834
# min               1.000000          1.000000            0.000000
# 25%               4.000000          7.000000           11.000000
# 50%               7.000000         15.000000           19.000000
# 75%              10.000000         22.000000           21.000000
# max              12.000000         31.000000           23.000000
#
#        Dates.Sighted.Minute  Dates.Documented.Year  Dates.Documented.Month  \
# count          60632.000000           60632.000000            60632.000000
# mean              17.718367            2007.401537                6.706063
# std               17.924455               4.480640                3.487636
# min                0.000000            1998.000000                1.000000
# 25%                0.000000            2004.000000                4.000000
# 50%               15.000000            2008.000000                7.000000
# 75%               30.000000            2012.000000               10.000000
# max               59.000000            2014.000000               12.000000
#
#        Dates.Documented.Day
# count          60632.000000
# mean              15.229219
# std                8.789173
# min                1.000000
# 25%                8.000000
# 50%               14.000000
# 75%               22.000000
# max               31.000000

# %% [markdown]
# **Missing/Outlier Data**
#
# **Data Preprocessing**
#
# **Exploratory Data Visualisations**

# %% [markdown]
# # Results

# %% [markdown]
# # Discussion
